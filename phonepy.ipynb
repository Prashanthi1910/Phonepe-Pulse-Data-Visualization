# %%
import os
import json
import pandas as pd
import mysql.connector

# %%
#aggre_insurance

path1="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/aggregated/insurance/country/india/state/"
agg_insur_list=os.listdir(path1)

columns1={"States":[],"Years":[],"Quarter":[],"Transaction_type":[],"Transaction_count":[],"Transaction_amount":[]}
for state in agg_insur_list:
    current_states= path1+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list:
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            A= json.load(data)
            for i in A["data"]["transactionData"]:
                name=i["name"]
                count=i["paymentInstruments"][0]["count"]
                amount=i["paymentInstruments"][0]["amount"]
                columns1["Transaction_type"].append(name)
                columns1["Transaction_count"].append(count)
                columns1["Transaction_amount"].append(amount)
                columns1["States"].append(state)
                columns1["Years"].append(year)
                columns1["Quarter"].append(int(file.strip(".json")))

aggre_insur=pd.DataFrame(columns1)

aggre_insur["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
aggre_insur["States"]=aggre_insur["States"].str.replace('-',' ')
aggre_insur["States"]=aggre_insur["States"].str.title()
aggre_insur["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
aggre_insur["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
# aggre_transactions

path2="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/aggregated/transaction/country/india/state/"
agg_trans_list= os.listdir(path2)

columns2={"States":[],"Years":[],"Quarter":[],"Transaction_type":[],"Transaction_count":[],"Transaction_amount":[]}
for state in agg_trans_list:
    current_states= path2+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list:
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            B= json.load(data)

            for i in B["data"]["transactionData"]:
                name=i["name"]
                count=i["paymentInstruments"][0]["count"]
                amount=i["paymentInstruments"][0]["amount"]
                columns2["Transaction_type"].append(name)
                columns2["Transaction_count"].append(count)
                columns2["Transaction_amount"].append(amount)
                columns2["States"].append(state)
                columns2["Years"].append(year)
                columns2["Quarter"].append(int(file.strip(".json")))

aggre_transaction=pd.DataFrame(columns2)

aggre_transaction["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
aggre_transaction["States"]=aggre_insur["States"].str.replace('-',' ')
aggre_transaction["States"]=aggre_insur["States"].str.title()
aggre_transaction["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
columns2
# Out:
# {'States': ['andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
#   'andaman-&-nicobar-islands',
# ...

# %%
aggre_transactions["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', nan], dtype=object)

# %%
#aggre_user
path3="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/aggregated/user/country/india/state/"
agg_user_list= os.listdir(path3)


columns3={"States":[],"Years":[],"Quarter":[],"Brands":[],"Transaction_count":[],"Percentage":[]}
for state in agg_trans_list:
    current_states= path3+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list:
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            C= json.load(data)
            try:
                for i in C["data"]["usersByDevice"]:
                    brand=i["brand"]
                    count=i["count"]
                    percentage=i["percentage"]
                    columns3["Brands"].append(brand)
                    columns3["Transaction_count"].append(count)
                    columns3["Percentage"].append(percentage)
                    columns3["States"].append(state)
                    columns3["Years"].append(year)
                    columns3["Quarter"].append(int(file.strip(".json")))
            except:
                pass

aggre_user=pd.DataFrame(columns3)

aggre_user["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
aggre_user["States"]=aggre_insur["States"].str.replace('-',' ')
aggre_user["States"]=aggre_insur["States"].str.title()
aggre_user["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
aggre_user["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', nan], dtype=object)

# %%
#map_insurance
path4="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/map/insurance/hover/country/india/state/"
map_insur_list=os.listdir(path4)

columns4={"States":[],"Years":[],"Quarter":[],"Districts":[],"Transaction_count":[],"Transaction_amount":[]}
for state in map_insur_list:
    current_states= path4+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list: 
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            D= json.load(data)
            for i in D["data"]["hoverDataList"]:
                name=i["name"]
                count=i["metric"][0]["count"]
                amount=i["metric"][0]["amount"]
                columns4["Districts"].append(name)
                columns4["Transaction_count"].append(count)
                columns4["Transaction_amount"].append(amount)
                columns4["States"].append(state)
                columns4["Years"].append(year)
                columns4["Quarter"].append(int(file.strip(".json")))
    
map_insur=pd.DataFrame(columns4)

map_insur["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_insur["States"]=aggre_insur["States"].str.replace('-',' ')
map_insur["States"]=aggre_insur["States"].str.title()
map_insur["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
map_insur["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', nan], dtype=object)

# %%
path5="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/map/transaction/hover/country/india/state/"
map_trans_list=os.listdir(path5)

columns5={"States":[],"Years":[],"Quarter":[],"Districts":[],"Transaction_count":[],"Transaction_amount":[]}
for state in map_trans_list:
    current_states= path5+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list: 
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            E= json.load(data)
            for i in E["data"]["hoverDataList"]:
                name=i["name"]
                count=i["metric"][0]["count"]
                amount=i["metric"][0]["amount"]
                columns5["Districts"].append(name)
                columns5["Transaction_count"].append(count)
                columns5["Transaction_amount"].append(amount)
                columns5["States"].append(state)
                columns5["Years"].append(year)
                columns5["Quarter"].append(int(file.strip(".json")))

map_trans=pd.DataFrame(columns5)

map_trans["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_trans["States"]=aggre_insur["States"].str.replace('-',' ')
map_trans["States"]=aggre_insur["States"].str.title()
map_trans["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
map_trans["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', nan], dtype=object)

# %%
path6="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/map/user/hover/country/india/state/"
map_user_list=os.listdir(path6)

columns6={"States":[],"Years":[],"Quarter":[],"Districts":[],"RegisteredUsers":[],"AppOpens":[]}
for state in map_user_list:
    current_states= path6+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list: 
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            F= json.load(data)
            for i in F["data"]["hoverData"].items():
                districts=i[0]
                registeredUsers=i[1]["registeredUsers"]
                appOpens=i[1]["appOpens"]
                columns6["Districts"].append(districts)
                columns6["RegisteredUsers"].append(registeredUsers)
                columns6["AppOpens"].append(appOpens)
                columns6["States"].append(state)
                columns6["Years"].append(year)
                columns6["Quarter"].append(int(file.strip(".json")))

map_user=pd.DataFrame(columns6)

map_user["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_user["States"]=aggre_insur["States"].str.replace('-',' ')
map_user["States"]=aggre_insur["States"].str.title()
map_user["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
map_user["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', nan], dtype=object)

# %%
#top_insur
path7="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/top/insurance/country/india/state/"
top_insur_list=os.listdir(path7)

columns7={"States":[],"Years":[],"Quarter":[],"Pincodes":[],"Transaction_count":[],"Transaction_amount":[]}
for state in top_insur_list:
    current_states= path7+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list: 
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            G= json.load(data)
            for i in G["data"]["pincodes"]:
                entityname=i["entityName"]
                count=i["metric"]["count"]
                amount=i["metric"]["amount"]
                columns7["Pincodes"].append(entityname)
                columns7["Transaction_count"].append(count)
                columns7["Transaction_amount"].append(amount)
                columns7["States"].append(state)
                columns7["Years"].append(year)
                columns7["Quarter"].append(int(file.strip(".json")))


top_insur=pd.DataFrame(columns7)

top_insur["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_insur["States"]=aggre_insur["States"].str.replace('-',' ')
top_insur["States"]=aggre_insur["States"].str.title()
top_insur["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
top_insur["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', nan], dtype=object)

# %%
#top_transaction

path8="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/top/transaction/country/india/state/"
top_trans_list=os.listdir(path8)

columns8={"States":[],"Years":[],"Quarter":[],"Pincodes":[],"Transaction_count":[],"Transaction_amount":[]}
for state in top_trans_list:
    current_states= path8+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list: 
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            H= json.load(data)
            for i in H["data"]["pincodes"]:
                entityname=i["entityName"]
                count=i["metric"]["count"]
                amount=i["metric"]["amount"]
                columns8["Pincodes"].append(entityname)
                columns8["Transaction_count"].append(count)
                columns8["Transaction_amount"].append(amount)
                columns8["States"].append(state)
                columns8["Years"].append(year)
                columns8["Quarter"].append(int(file.strip(".json")))

top_trans=pd.DataFrame(columns8)


top_trans["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_trans["States"]=aggre_insur["States"].str.replace('-',' ')
top_trans["States"]=aggre_insur["States"].str.title()
top_trans["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
top_trans["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', nan], dtype=object)

# %%
#top_user_list
path9="C:/Users/Praveena/OneDrive/Desktop/projects/phone pe/pulse/data/top/user/country/india/state/"
top_user_list=os.listdir(path9)

columns9={"States":[],"Years":[],"Quarter":[],"Pincodes":[],"RegisteredUsers":[]}
for state in top_user_list:
    current_states= path9+state+"/"
    agg_year_list=os.listdir(current_states)
    
    for year in agg_year_list: 
        current_year=current_states+year+"/"
        agg_file_list=os.listdir(current_year)
        
        for file in agg_file_list:
            current_file=current_year+file
            data=open(current_file,"r")

            I= json.load(data)
            for i in I["data"]["pincodes"]:
                entityname=i["name"]
                registeredusers=i["registeredUsers"]
                columns9["Pincodes"].append(entityname)
                columns9["RegisteredUsers"].append(registeredusers)
                columns9["States"].append(state)
                columns9["Years"].append(year)
                columns9["Quarter"].append(int(file.strip(".json")))


top_user=pd.DataFrame(columns9)

top_user["States"]=aggre_insur["States"].str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_user["States"]=aggre_insur["States"].str.replace('-',' ')
top_user["States"]=aggre_insur["States"].str.title()
top_user["States"]=aggre_insur["States"].str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')

# %%
top_user["States"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', nan], dtype=object)

# %%
#sql Connection
mydb = mysql.connector.connect(
        host='localhost',
        user='root',
        password='Prashanthi@19',
        database='phonepe_data'
    )

cursor = mydb.cursor()

#aggregated_insurance_table

sql_create_table1= '''CREATE TABLE if not exists aggregated_insurance(State varchar(255),
                                        Years int,
                                        Quarter int,
                                        Transaction_type varchar(255),
                                        Transaction_count bigint,
                                        Transaction_amount bigint)'''
cursor.execute(sql_create_table1)

sql_insert_data1=''' INSERT INTO aggregated_insurance(State,Years,Quarter,Transaction_type,
                                        Transaction_count,
                                        Transaction_amount)
                                        values(%s,%s,%s,%s,%s,%s)'''

data1=aggre_insur.values.tolist()
cursor.executemany(sql_insert_data1,data1)
mydb.commit()

#aggregated transactions

# Create table if not exists
sql_create_table2 = '''CREATE TABLE IF NOT EXISTS aggregated_transactions (
    State VARCHAR(255),
    Years INT,
    Quarter INT,
    Transaction_type VARCHAR(255),
    Transaction_count BIGINT,
    Transaction_amount BIGINT
)'''

cursor.execute(sql_create_table2)

# Insert data into the table
sql_insert_data2 = '''INSERT INTO aggregated_transactions (
    State, Years, Quarter, Transaction_type, Transaction_count, Transaction_amount
) VALUES (%s, %s, %s, %s, %s, %s)'''

data2 = aggre_transaction.values.tolist()

try:
    cursor.executemany(sql_insert_data2, data2)
    mydb.commit()  # Commit the transaction
    print("Data inserted successfully!")
except mysql.connector.Error as err:
    print("Error:", err)

#aggregated_user


# Create table if not exists
sql_create_table3 = '''CREATE TABLE IF NOT EXISTS aggregated_user (
    State VARCHAR(255),
    Years INT,
    Quarter INT,
    Brands VARCHAR(255),
    Transaction_count BIGINT,
    Percentage float
)'''

cursor.execute(sql_create_table3)

# Insert data into the table
sql_insert_data3 = '''INSERT INTO aggregated_user (
    State, Years, Quarter, Brands, Transaction_count, Percentage
) VALUES (%s, %s, %s, %s, %s, %s)'''

data3 = aggre_user.values.tolist()

try:
    cursor.executemany(sql_insert_data3, data3)
    mydb.commit()  # Commit the transaction
    print("Data inserted successfully!")
except mysql.connector.Error as err:
    print("Error:", err)

#map_insurance

# Create table if not exists
sql_create_table4 = '''CREATE TABLE IF NOT EXISTS map_insurance (
    State VARCHAR(255),
    Years INT,
    Quarter INT,
    Districts VARCHAR(255),
    Transaction_count BIGINT,
    Transaction_amount BIGINT
)'''

cursor.execute(sql_create_table4)

# Insert data into the table
sql_insert_data4 = '''INSERT INTO map_insurance (
    State, Years, Quarter, Districts, Transaction_count, Transaction_amount
) VALUES (%s, %s, %s, %s, %s, %s)'''

data4 = map_insur.values.tolist()

try:
    cursor.executemany(sql_insert_data4, data4)
    mydb.commit()  # Commit the transaction
    print("Data inserted successfully!")
except mysql.connector.Error as err:
    print("Error:", err)


#map_transaction

# Create table if not exists
sql_create_table5 = '''CREATE TABLE IF NOT EXISTS map_transaction (
    State VARCHAR(255),
    Years INT,
    Quarter INT,
    Districts VARCHAR(255),
    Transaction_count BIGINT,
    Transaction_amount BIGINT
)'''

cursor.execute(sql_create_table5)

# Insert data into the table
sql_insert_data5 = '''INSERT INTO map_transaction (
    State, Years, Quarter, Districts, Transaction_count, Transaction_amount
) VALUES (%s, %s, %s, %s, %s, %s)'''

data5 = map_trans.values.tolist()

try:
    cursor.executemany(sql_insert_data5, data5)
    mydb.commit()  # Commit the transaction
    print("Data inserted successfully!")
except mysql.connector.Error as err:
    print("Error:", err)


#map_user

# Create table if not exists
sql_create_table6 = '''CREATE TABLE IF NOT EXISTS map_user (
    State VARCHAR(255),
    Years INT,
    Quarter INT,
    Districts VARCHAR(255),
    Registered_Users BIGINT,
    App_Opens BIGINT
)'''

cursor.execute(sql_create_table6)

# Insert data into the table
sql_insert_data6 = '''INSERT INTO map_user (
    State, Years, Quarter, Districts, Registered_Users, App_Opens
) VALUES (%s, %s, %s, %s, %s, %s)'''

data6 = map_user.values.tolist()

try:
    cursor.executemany(sql_insert_data6, data6)
    mydb.commit()  # Commit the transaction
    print("Data inserted successfully!")
except mysql.connector.Error as err:
    print("Error:", err)


#top_insurance

# Create table if not exists
sql_create_table7 = '''CREATE TABLE IF NOT EXISTS top_insurance (
    State VARCHAR(255),
    Years INT,
    Quarter INT,
    Pincodes VARCHAR(255),
    Transaction_count BIGINT,
    Transaction_amount BIGINT
)'''

cursor.execute(sql_create_table7)

# Insert data into the table
sql_insert_data7 = '''INSERT INTO top_insurance (
    State, Years, Quarter, Pincodes, Transaction_count, Transaction_amount
) VALUES (%s, %s, %s, %s, %s, %s)'''

data7 = top_insur.values.tolist()

try:
    cursor.executemany(sql_insert_data7, data7)
    mydb.commit()  # Commit the transaction
    print("Data inserted successfully!")
except mysql.connector.Error as err:
    print("Error:", err)


#top_transactions

# Create table if not exists
sql_create_table8 = '''CREATE TABLE IF NOT EXISTS top_transaction (
    State VARCHAR(255),
    Years INT,
    Quarter INT,
    Pincodes VARCHAR(255),
    Transaction_count BIGINT,
    Transaction_amount BIGINT
)'''

cursor.execute(sql_create_table8)

# Insert data into the table
sql_insert_data8 = '''INSERT INTO top_transaction (
    State, Years, Quarter, Pincodes, Transaction_count, Transaction_amount
) VALUES (%s, %s, %s, %s, %s, %s)'''

data8 = top_trans.values.tolist()

try:
    cursor.executemany(sql_insert_data8, data8)
    mydb.commit()  # Commit the transaction
    print("Data inserted successfully!")
except mysql.connector.Error as err:
    print("Error:", err)


#top_user

# Create table if not exists
sql_create_table9 = '''CREATE TABLE IF NOT EXISTS top_user (
    State VARCHAR(255),
    Years INT,
    Quarter INT,
    Pincodes VARCHAR(255),
    Registered_Users BIGINT
    
)'''

cursor.execute(sql_create_table9)

# Insert data into the table
sql_insert_data9 = '''INSERT INTO top_user (
    State, Years, Quarter, Pincodes, Registered_Users
) VALUES (%s, %s, %s, %s, %s)'''

data9 = top_user.values.tolist()

try:
    cursor.executemany(sql_insert_data9, data9)
    mydb.commit()  # Commit the transaction
    print("Data inserted successfully!")
except mysql.connector.Error as err:
    print("Error:", err)

cursor.close()
mydb.close()
# Out:
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!
